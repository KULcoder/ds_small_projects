# %%
from sklearnex import patch_sklearn
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# # Unsupervised Learning Techniques
# ## Clusterings

# %%
# firstly, generating data: some blobs
from sklearn.datasets import make_blobs

blob_centers = np.array([
    [0.2, 2.3],
    [-1.5, 2.3],
    [-2.8, 1.8],
    [-2.8, 2.8],
    [-2.8, 1.3]
])
blob_std = np.array([0.4, 0.3, 0.1, 0.1, 0.1])

X, y = make_blobs(n_samples=2000, centers=blob_centers, 
                 cluster_std=blob_std, random_state=7)

# %%
# plot the graph
def plot_clusters(X, y=None):
    plt.scatter(X[:, 0], X[:, 1], c=y, s=1)
    plt.xlabel("$x_1$", fontsize=14)
    plt.ylabel("$x_2$", fontsize=14, rotation=0)

# %%
plt.figure(figsize=(8, 4))
plot_clusters(X)
plt.show()

# %%
# K-Means clustering
from sklearn.cluster import KMeans
k = 5
kmeans = KMeans(n_clusters=k)
y_pred = kmeans.fit_predict(X)

# %%
kmeans.labels_ # equal to y_pred
# Out:
# array([4, 0, 1, ..., 2, 1, 0])

# %%
kmeans.cluster_centers_
# Out:
# array([[-2.80389616,  1.80117999],
#        [ 0.20876306,  2.25551336],
#        [-2.79290307,  2.79641063],
#        [-1.46679593,  2.28585348],
#        [-2.80037642,  1.30082566]])

# %%
# helper function
def plot_data(X):
    plt.plot(X[:, 0], X[:, 1], 'k.', markersize=2)

def plot_centroids(centroids, weights=None, circle_color='w', cross_color='k'):
    if weights is not None:
        centroids = centroids[weights > weights.max() / 10]
    plt.scatter(centroids[:, 0], centroids[:, 1],
                marker='o', s=35, linewidths=8,
                color=circle_color, zorder=10, alpha=0.9)
    plt.scatter(centroids[:, 0], centroids[:, 1],
                marker='x', s=2, linewidths=12,
                color=cross_color, zorder=11, alpha=1)

def plot_decision_boundaries(clusterer, X, resolution=1000, show_centroids=True,
                             show_xlabels=True, show_ylabels=True):
    mins = X.min(axis=0) - 0.1
    maxs = X.max(axis=0) + 0.1
    xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution),
                         np.linspace(mins[1], maxs[1], resolution))
    Z = clusterer.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                cmap="Pastel2")
    plt.contour(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                linewidths=1, colors='k')
    plot_data(X)
    if show_centroids:
        plot_centroids(clusterer.cluster_centers_)

    if show_xlabels:
        plt.xlabel("$x_1$", fontsize=14)
    else:
        plt.tick_params(labelbottom=False)
    if show_ylabels:
        plt.ylabel("$x_2$", fontsize=14, rotation=0)
    else:
        plt.tick_params(labelleft=False)

# %%
# visulize the decision boundries 
plt.figure(figsize=(8, 4))
plot_decision_boundaries(kmeans, X)
plt.show()

# %%
# make out a few instances to test on
X_new = np.array([[0, 2], [3, 2], [-3, 3], [-3, 2.5]])

# %%
# kmeans predict the class it belongs
kmeans.predict(X_new)
# Out:
# array([1, 1, 2, 2])

# %%
# gives the distance from each instance to every centroid
kmeans.transform(X_new)
# Out:
# array([[2.81093633, 0.32995317, 2.9042344 , 1.49439034, 2.88633901],
#        [5.80730058, 2.80290755, 5.84739223, 4.4759332 , 5.84236351],
#        [1.21475352, 3.29399768, 0.29040966, 1.69136631, 1.71086031],
#        [0.72581411, 3.21806371, 0.36159148, 1.54808703, 1.21567622]])

# %% [markdown]
# Notice this is a k-dimensional dataset: a tranformation!
# - can be very efficient nonlinear dimensionality reduction technique

# %% [markdown]
# ## Mini-batch K-Means

# %%
# application of mini-batch k-means
from sklearn.cluster import MiniBatchKMeans

minibatch_kmeans = MiniBatchKMeans(n_clusters=5, batch_size = 2048) # might cause memory leakage with MKL
minibatch_kmeans.fit(X)
# Out:
# MiniBatchKMeans(batch_size=2048, n_clusters=5)

# %% [markdown]
# ## Finding Optimal K Number

# %% [markdown]
# ### By Check Inertia

# %%
# notice that this block of code have conflict with intel patch_sklearn
kmeans_per_k = [KMeans(n_clusters=k, random_state=42).fit(X)
                for k in range(1, 10)]
inertias = [model.inertia_ for model in kmeans_per_k]

# %%
plt.figure(figsize=(8, 3.5))
plt.plot(range(1, 10), inertias, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Inertia", fontsize=14)
plt.annotate('Elbow',
             xy=(4, inertias[3]),
             xytext=(0.55, 0.55),
             textcoords='figure fraction',
             fontsize=16,
             arrowprops=dict(facecolor='black', shrink=0.1)
            )
plt.axis([1, 8.5, 0, 1300])
plt.show()

# %% [markdown]
# ### By Checking Sklhouette Score

# %%
# simple applicaion of Sklhouette Score
from sklearn.metrics import silhouette_score
silhouette_score(X, kmeans.labels_)
# Out:
# 0.655517642572828

# %%
# generate Sklhouette scores
silhouette_scores = [silhouette_score(X, model.labels_)
                     for model in kmeans_per_k[1:]]

# %%
# generate graph
plt.figure(figsize=(8, 3))
plt.plot(range(2, 10), silhouette_scores, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Silhouette score", fontsize=14)
plt.axis([1.8, 8.5, 0.55, 0.7])
plt.show()

# %%
# plot the Sklhoueete Diagram
from sklearn.metrics import silhouette_samples
from matplotlib.ticker import FixedLocator, FixedFormatter

plt.figure(figsize=(11, 9))

for k in (3, 4, 5, 6):
    plt.subplot(2, 2, k - 2)
    
    y_pred = kmeans_per_k[k - 1].labels_
    silhouette_coefficients = silhouette_samples(X, y_pred)

    padding = len(X) // 30
    pos = padding
    ticks = []
    for i in range(k):
        coeffs = silhouette_coefficients[y_pred == i]
        coeffs.sort()

        color = mpl.cm.Spectral(i / k)
        plt.fill_betweenx(np.arange(pos, pos + len(coeffs)), 0, coeffs,
                          facecolor=color, edgecolor=color, alpha=0.7)
        ticks.append(pos + len(coeffs) // 2)
        pos += len(coeffs) + padding

    plt.gca().yaxis.set_major_locator(FixedLocator(ticks))
    plt.gca().yaxis.set_major_formatter(FixedFormatter(range(k)))
    if k in (3, 5):
        plt.ylabel("Cluster")
    
    if k in (5, 6):
        plt.gca().set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
        plt.xlabel("Silhouette Coefficient")
    else:
        plt.tick_params(labelbottom=False)

    plt.axvline(x=silhouette_scores[k - 2], color="red", linestyle="--")
    plt.title("$k={}$".format(k), fontsize=16)

plt.show()

# %% [markdown]
# ## Application of Clustering with K-Means

# %% [markdown]
# ### Image Segmentation

# %%
# An application of Color Segmentation with K-Means
from matplotlib.image import imread # or from imageio
image = imread("ladybug.png")
image.shape
# three dimensions: first height, second width, third color channels
# Out:
# (533, 800, 3)

# %%
# cluster the colors
X = image.reshape(-1, 3)
kmeans = KMeans(n_clusters=8).fit(X)
segmented_img = kmeans.cluster_centers_[kmeans.labels_] # replace each pixel with their cluster center, a np grammar
segmented_img = segmented_img.reshape(image.shape)

# %%
# original graph
plt.imshow(image)

# %%
# 8 colors
plt.imshow(segmented_img)

# %% [markdown]
# ### Using Clustering for Preprocessing
# Use a MNIST-like dataset to show how clustering can improve supervised ml performance

# %%
# generate dataset
from sklearn.datasets import load_digits

X_digits, y_digits = load_digits(return_X_y=True)

# train-test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_digits, y_digits)

# train on a Logistic Regression model
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(max_iter=10000)
log_reg.fit(X_train, y_train)

# evaluate the model
log_reg.score(X_test, y_test)
# Out:
# 0.9622222222222222

# %%
# plug the clustering into the preprocessing step
from sklearn.pipeline import Pipeline

# set up the pipeline
pipeline = Pipeline([
    ("kmeans", KMeans(n_clusters=50)),
    ("log_reg", LogisticRegression(max_iter=50000)),
])

# fit on the pipeline
pipeline.fit(X_train, y_train)

# evaluate this pipeline
pipeline.score(X_test, y_test)
# Out:
# 0.9711111111111111

# %%
# %%time
# this might lead to a long time 
from sklearn.model_selection import GridSearchCV

param_grid = dict(kmeans__n_clusters=range(2, 100))
grid_clf = GridSearchCV(pipeline, param_grid, cv=3, verbose=2)
grid_clf.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 98 candidates, totalling 294 fits
# [CV] END ...............................kmeans__n_clusters=2; total time=   0.4s
# [CV] END ...............................kmeans__n_clusters=2; total time=   0.5s
# [CV] END ...............................kmeans__n_clusters=2; total time=   1.0s
# [CV] END ...............................kmeans__n_clusters=3; total time=   1.4s
# [CV] END ...............................kmeans__n_clusters=3; total time=   1.2s
# [CV] END ...............................kmeans__n_clusters=3; total time=   1.1s
# [CV] END ...............................kmeans__n_clusters=4; total time=   1.2s
# [CV] END ...............................kmeans__n_clusters=4; total time=   1.2s
# [CV] END ...............................kmeans__n_clusters=4; total time=   1.9s
# [CV] END ...............................kmeans__n_clusters=5; total time=   2.9s
# [CV] END ...............................kmeans__n_clusters=5; total time=   1.5s
# [CV] END ...............................kmeans__n_clusters=5; total time=   2.9s
# [CV] END ...............................kmeans__n_clusters=6; total time=   5.0s
# [CV] END ...............................kmeans__n_clusters=6; total time=   3.7s
# [CV] END ...............................kmeans__n_clusters=6; total time=   2.9s
# [CV] END ...............................kmeans__n_clusters=7; total time=   5.6s
# [CV] END ...............................kmeans__n_clusters=7; total time=   3.6s
# [CV] END ...............................kmeans__n_clusters=7; total time=   3.2s
# [CV] END ...............................kmeans__n_clusters=8; total time=   3.8s
# [CV] END ...............................kmeans__n_clusters=8; total time=   5.7s
# [CV] END ...............................kmeans__n_clusters=8; total time=   4.4s
# [CV] END ...............................kmeans__n_clusters=9; total time=   6.9s
# [CV] END ...............................kmeans__n_clusters=9; total time=   8.4s
# [CV] END ...............................kmeans__n_clusters=9; total time=   9.8s
# [CV] END ..............................kmeans__n_clusters=10; total time=   5.7s
# [CV] END ..............................kmeans__n_clusters=10; total time=   9.1s
# [CV] END ..............................kmeans__n_clusters=10; total time=   7.1s
# [CV] END ..............................kmeans__n_clusters=11; total time=   8.1s
# [CV] END ..............................kmeans__n_clusters=11; total time=   6.5s
# [CV] END ..............................kmeans__n_clusters=11; total time=   8.4s
# [CV] END ..............................kmeans__n_clusters=12; total time=   9.1s
# [CV] END ..............................kmeans__n_clusters=12; total time=   6.5s
# [CV] END ..............................kmeans__n_clusters=12; total time=   9.9s
# [CV] END ..............................kmeans__n_clusters=13; total time=   9.2s
# [CV] END ..............................kmeans__n_clusters=13; total time=   8.3s
# [CV] END ..............................kmeans__n_clusters=13; total time=   9.1s
# [CV] END ..............................kmeans__n_clusters=14; total time=   8.0s
# [CV] END ..............................kmeans__n_clusters=14; total time=  10.1s
# [CV] END ..............................kmeans__n_clusters=14; total time=   7.9s
# [CV] END ..............................kmeans__n_clusters=15; total time=   9.9s
# [CV] END ..............................kmeans__n_clusters=15; total time=   7.4s
# [CV] END ..............................kmeans__n_clusters=15; total time=   7.7s
# [CV] END ..............................kmeans__n_clusters=16; total time=   7.0s
# [CV] END ..............................kmeans__n_clusters=16; total time=   5.6s
# [CV] END ..............................kmeans__n_clusters=16; total time=   8.7s
# [CV] END ..............................kmeans__n_clusters=17; total time=   8.1s
# [CV] END ..............................kmeans__n_clusters=17; total time=   8.2s
# [CV] END ..............................kmeans__n_clusters=17; total time=   6.4s
# [CV] END ..............................kmeans__n_clusters=18; total time=   5.6s
# [CV] END ..............................kmeans__n_clusters=18; total time=   5.3s
# [CV] END ..............................kmeans__n_clusters=18; total time=  10.3s
# [CV] END ..............................kmeans__n_clusters=19; total time=   6.4s
# [CV] END ..............................kmeans__n_clusters=19; total time=   9.8s
# C:\Users\keyuu\anaconda3\envs\iaat\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END ..............................kmeans__n_clusters=19; total time=  10.2s
# [CV] END ..............................kmeans__n_clusters=20; total time=   6.3s
# [CV] END ..............................kmeans__n_clusters=20; total time=   7.1s
# C:\Users\keyuu\anaconda3\envs\iaat\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END ..............................kmeans__n_clusters=20; total time=  10.4s
# [CV] END ..............................kmeans__n_clusters=21; total time=   8.1s
# [CV] END ..............................kmeans__n_clusters=21; total time=   7.5s
# [CV] END ..............................kmeans__n_clusters=21; total time=   5.6s
# [CV] END ..............................kmeans__n_clusters=22; total time=   5.9s
# [CV] END ..............................kmeans__n_clusters=22; total time=   7.1s
# [CV] END ..............................kmeans__n_clusters=22; total time=   4.0s
# [CV] END ..............................kmeans__n_clusters=23; total time=   4.1s
# [CV] END ..............................kmeans__n_clusters=23; total time=   5.6s
# [CV] END ..............................kmeans__n_clusters=23; total time=   8.6s
# [CV] END ..............................kmeans__n_clusters=24; total time=   7.4s
# [CV] END ..............................kmeans__n_clusters=24; total time=   9.1s
# [CV] END ..............................kmeans__n_clusters=24; total time=   5.0s
# [CV] END ..............................kmeans__n_clusters=25; total time=   7.3s
# [CV] END ..............................kmeans__n_clusters=25; total time=   4.9s
# [CV] END ..............................kmeans__n_clusters=25; total time=   6.0s
# [CV] END ..............................kmeans__n_clusters=26; total time=  10.5s
# [CV] END ..............................kmeans__n_clusters=26; total time=   5.5s
# [CV] END ..............................kmeans__n_clusters=26; total time=  10.7s
# [CV] END ..............................kmeans__n_clusters=27; total time=   8.2s
# [CV] END ..............................kmeans__n_clusters=27; total time=   6.3s
# [CV] END ..............................kmeans__n_clusters=27; total time=   5.1s
# [CV] END ..............................kmeans__n_clusters=28; total time=   4.1s
# [CV] END ..............................kmeans__n_clusters=28; total time=   5.3s
# [CV] END ..............................kmeans__n_clusters=28; total time=   4.1s
# [CV] END ..............................kmeans__n_clusters=29; total time=   8.1s
# [CV] END ..............................kmeans__n_clusters=29; total time=   8.3s
# [CV] END ..............................kmeans__n_clusters=29; total time=   7.1s
# [CV] END ..............................kmeans__n_clusters=30; total time=   6.7s
# [CV] END ..............................kmeans__n_clusters=30; total time=   8.1s
# [CV] END ..............................kmeans__n_clusters=30; total time=  10.9s
# [CV] END ..............................kmeans__n_clusters=31; total time=   7.0s
# [CV] END ..............................kmeans__n_clusters=31; total time=   7.7s
# [CV] END ..............................kmeans__n_clusters=31; total time=   4.8s
# [CV] END ..............................kmeans__n_clusters=32; total time=   4.7s
# [CV] END ..............................kmeans__n_clusters=32; total time=   5.2s
# [CV] END ..............................kmeans__n_clusters=32; total time=   5.8s
# [CV] END ..............................kmeans__n_clusters=33; total time=   4.7s
# [CV] END ..............................kmeans__n_clusters=33; total time=   8.9s
# [CV] END ..............................kmeans__n_clusters=33; total time=   4.9s
# [CV] END ..............................kmeans__n_clusters=34; total time=   6.9s
# [CV] END ..............................kmeans__n_clusters=34; total time=   4.1s
# [CV] END ..............................kmeans__n_clusters=34; total time=   5.9s
# [CV] END ..............................kmeans__n_clusters=35; total time=   3.0s
# [CV] END ..............................kmeans__n_clusters=35; total time=   4.3s
# [CV] END ..............................kmeans__n_clusters=35; total time=   5.7s
# [CV] END ..............................kmeans__n_clusters=36; total time=   6.6s
# [CV] END ..............................kmeans__n_clusters=36; total time=   4.4s
# [CV] END ..............................kmeans__n_clusters=36; total time=   5.9s
# [CV] END ..............................kmeans__n_clusters=37; total time=   5.7s
# [CV] END ..............................kmeans__n_clusters=37; total time=   7.0s
# [CV] END ..............................kmeans__n_clusters=37; total time=   9.7s
# [CV] END ..............................kmeans__n_clusters=38; total time=   3.4s
# [CV] END ..............................kmeans__n_clusters=38; total time=   4.4s
# [CV] END ..............................kmeans__n_clusters=38; total time=   5.7s
# [CV] END ..............................kmeans__n_clusters=39; total time=   4.5s
# [CV] END ..............................kmeans__n_clusters=39; total time=   7.3s
# [CV] END ..............................kmeans__n_clusters=39; total time=   4.5s
# [CV] END ..............................kmeans__n_clusters=40; total time=   4.6s
# [CV] END ..............................kmeans__n_clusters=40; total time=   6.1s
# [CV] END ..............................kmeans__n_clusters=40; total time=   7.3s
# [CV] END ..............................kmeans__n_clusters=41; total time=   4.7s
# [CV] END ..............................kmeans__n_clusters=41; total time=  10.1s
# [CV] END ..............................kmeans__n_clusters=41; total time=   7.8s
# [CV] END ..............................kmeans__n_clusters=42; total time=   6.5s
# [CV] END ..............................kmeans__n_clusters=42; total time=   6.8s
# [CV] END ..............................kmeans__n_clusters=42; total time=   7.6s
# [CV] END ..............................kmeans__n_clusters=43; total time=   5.4s
# [CV] END ..............................kmeans__n_clusters=43; total time=   4.0s
# [CV] END ..............................kmeans__n_clusters=43; total time=   8.0s
# [CV] END ..............................kmeans__n_clusters=44; total time=   6.7s
# [CV] END ..............................kmeans__n_clusters=44; total time=   4.3s
# [CV] END ..............................kmeans__n_clusters=44; total time=   5.1s
# [CV] END ..............................kmeans__n_clusters=45; total time=   6.5s
# [CV] END ..............................kmeans__n_clusters=45; total time=   5.6s
# [CV] END ..............................kmeans__n_clusters=45; total time=   5.7s
# [CV] END ..............................kmeans__n_clusters=46; total time=   3.7s
# [CV] END ..............................kmeans__n_clusters=46; total time=   7.1s
# [CV] END ..............................kmeans__n_clusters=46; total time=   7.2s
# [CV] END ..............................kmeans__n_clusters=47; total time=   5.1s
# [CV] END ..............................kmeans__n_clusters=47; total time=   5.1s
# C:\Users\keyuu\anaconda3\envs\iaat\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV] END ..............................kmeans__n_clusters=47; total time=  12.1s
# [CV] END ..............................kmeans__n_clusters=48; total time=   3.2s
# [CV] END ..............................kmeans__n_clusters=48; total time=   7.1s
# [CV] END ..............................kmeans__n_clusters=48; total time=   5.0s
# [CV] END ..............................kmeans__n_clusters=49; total time=   3.5s
# [CV] END ..............................kmeans__n_clusters=49; total time=   3.9s
# [CV] END ..............................kmeans__n_clusters=49; total time=   6.4s
# [CV] END ..............................kmeans__n_clusters=50; total time=   3.0s
# [CV] END ..............................kmeans__n_clusters=50; total time=   4.0s
# [CV] END ..............................kmeans__n_clusters=50; total time=   5.4s
# [CV] END ..............................kmeans__n_clusters=51; total time=   4.9s
# [CV] END ..............................kmeans__n_clusters=51; total time=   4.5s
# [CV] END ..............................kmeans__n_clusters=51; total time=   5.7s
# [CV] END ..............................kmeans__n_clusters=52; total time=   3.1s
# [CV] END ..............................kmeans__n_clusters=52; total time=   5.5s
# [CV] END ..............................kmeans__n_clusters=52; total time=   5.9s
# [CV] END ..............................kmeans__n_clusters=53; total time=   7.1s
# [CV] END ..............................kmeans__n_clusters=53; total time=   5.0s
# [CV] END ..............................kmeans__n_clusters=53; total time=   7.1s
# [CV] END ..............................kmeans__n_clusters=54; total time=   5.7s
# [CV] END ..............................kmeans__n_clusters=54; total time=   4.5s
# [CV] END ..............................kmeans__n_clusters=54; total time=   9.1s
# [CV] END ..............................kmeans__n_clusters=55; total time=   7.2s
# [CV] END ..............................kmeans__n_clusters=55; total time=   7.1s
# [CV] END ..............................kmeans__n_clusters=55; total time=   5.1s
# [CV] END ..............................kmeans__n_clusters=56; total time=   4.6s
# [CV] END ..............................kmeans__n_clusters=56; total time=   3.9s
# [CV] END ..............................kmeans__n_clusters=56; total time=   8.6s
# [CV] END ..............................kmeans__n_clusters=57; total time=   3.4s
# [CV] END ..............................kmeans__n_clusters=57; total time=   3.0s
# [CV] END ..............................kmeans__n_clusters=57; total time=   7.0s
# [CV] END ..............................kmeans__n_clusters=58; total time=   9.2s
# [CV] END ..............................kmeans__n_clusters=58; total time=   2.8s
# [CV] END ..............................kmeans__n_clusters=58; total time=   6.8s
# [CV] END ..............................kmeans__n_clusters=59; total time=   5.8s
# [CV] END ..............................kmeans__n_clusters=59; total time=   3.4s
# [CV] END ..............................kmeans__n_clusters=59; total time=   8.6s
# [CV] END ..............................kmeans__n_clusters=60; total time=   5.7s
# [CV] END ..............................kmeans__n_clusters=60; total time=   4.2s
# [CV] END ..............................kmeans__n_clusters=60; total time=  10.6s
# [CV] END ..............................kmeans__n_clusters=61; total time=   8.1s
# [CV] END ..............................kmeans__n_clusters=61; total time=   3.0s
# [CV] END ..............................kmeans__n_clusters=61; total time=   9.8s
# [CV] END ..............................kmeans__n_clusters=62; total time=   4.6s
# [CV] END ..............................kmeans__n_clusters=62; total time=   3.0s
# [CV] END ..............................kmeans__n_clusters=62; total time=   7.5s
# [CV] END ..............................kmeans__n_clusters=63; total time=   5.0s
# [CV] END ..............................kmeans__n_clusters=63; total time=   3.3s
# [CV] END ..............................kmeans__n_clusters=63; total time=   5.4s
# [CV] END ..............................kmeans__n_clusters=64; total time=   8.5s
# [CV] END ..............................kmeans__n_clusters=64; total time=   3.0s
# [CV] END ..............................kmeans__n_clusters=64; total time=   5.8s
# [CV] END ..............................kmeans__n_clusters=65; total time=   7.6s
# [CV] END ..............................kmeans__n_clusters=65; total time=   3.5s
# [CV] END ..............................kmeans__n_clusters=65; total time=   6.7s
# [CV] END ..............................kmeans__n_clusters=66; total time=   4.5s
# [CV] END ..............................kmeans__n_clusters=66; total time=   3.3s
# [CV] END ..............................kmeans__n_clusters=66; total time=   5.0s
# [CV] END ..............................kmeans__n_clusters=67; total time=  10.1s
# [CV] END ..............................kmeans__n_clusters=67; total time=   6.6s
# [CV] END ..............................kmeans__n_clusters=67; total time=  10.3s
# [CV] END ..............................kmeans__n_clusters=68; total time=   3.8s
# [CV] END ..............................kmeans__n_clusters=68; total time=   5.2s
# [CV] END ..............................kmeans__n_clusters=68; total time=   6.5s
# [CV] END ..............................kmeans__n_clusters=69; total time=  10.3s
# [CV] END ..............................kmeans__n_clusters=69; total time=   4.6s
# [CV] END ..............................kmeans__n_clusters=69; total time=   4.5s
# [CV] END ..............................kmeans__n_clusters=70; total time=   5.0s
# [CV] END ..............................kmeans__n_clusters=70; total time=   4.6s
# [CV] END ..............................kmeans__n_clusters=70; total time=   6.7s
# [CV] END ..............................kmeans__n_clusters=71; total time=   4.8s
# [CV] END ..............................kmeans__n_clusters=71; total time=   5.9s
# [CV] END ..............................kmeans__n_clusters=71; total time=   6.9s
# [CV] END ..............................kmeans__n_clusters=72; total time=   5.6s
# [CV] END ..............................kmeans__n_clusters=72; total time=   3.8s
# [CV] END ..............................kmeans__n_clusters=72; total time=  11.1s
# [CV] END ..............................kmeans__n_clusters=73; total time=   7.1s
# [CV] END ..............................kmeans__n_clusters=73; total time=   4.9s
# [CV] END ..............................kmeans__n_clusters=73; total time=   5.7s
# [CV] END ..............................kmeans__n_clusters=74; total time=   5.9s
# [CV] END ..............................kmeans__n_clusters=74; total time=   4.5s
# [CV] END ..............................kmeans__n_clusters=74; total time=   8.7s
# [CV] END ..............................kmeans__n_clusters=75; total time=   3.7s
# [CV] END ..............................kmeans__n_clusters=75; total time=   3.5s
# [CV] END ..............................kmeans__n_clusters=75; total time=   4.8s
# [CV] END ..............................kmeans__n_clusters=76; total time=   7.2s
# [CV] END ..............................kmeans__n_clusters=76; total time=   5.3s
# [CV] END ..............................kmeans__n_clusters=76; total time=   5.7s
# [CV] END ..............................kmeans__n_clusters=77; total time=   7.0s
# [CV] END ..............................kmeans__n_clusters=77; total time=   3.5s
# [CV] END ..............................kmeans__n_clusters=77; total time=   4.6s
# [CV] END ..............................kmeans__n_clusters=78; total time=   4.1s
# [CV] END ..............................kmeans__n_clusters=78; total time=   3.4s
# [CV] END ..............................kmeans__n_clusters=78; total time=   5.7s
# [CV] END ..............................kmeans__n_clusters=79; total time=   4.0s
# [CV] END ..............................kmeans__n_clusters=79; total time=   6.6s
# [CV] END ..............................kmeans__n_clusters=79; total time=   6.0s
# [CV] END ..............................kmeans__n_clusters=80; total time=   4.3s
# [CV] END ..............................kmeans__n_clusters=80; total time=   3.5s
# [CV] END ..............................kmeans__n_clusters=80; total time=   6.8s
# [CV] END ..............................kmeans__n_clusters=81; total time=   6.5s
# [CV] END ..............................kmeans__n_clusters=81; total time=   5.5s
# [CV] END ..............................kmeans__n_clusters=81; total time=   6.6s
# [CV] END ..............................kmeans__n_clusters=82; total time=   3.7s
# [CV] END ..............................kmeans__n_clusters=82; total time=   3.5s
# [CV] END ..............................kmeans__n_clusters=82; total time=   5.6s
# [CV] END ..............................kmeans__n_clusters=83; total time=   5.0s
# [CV] END ..............................kmeans__n_clusters=83; total time=   6.7s
# [CV] END ..............................kmeans__n_clusters=83; total time=   6.4s
# [CV] END ..............................kmeans__n_clusters=84; total time=   4.6s
# [CV] END ..............................kmeans__n_clusters=84; total time=   5.2s
# [CV] END ..............................kmeans__n_clusters=84; total time=   9.2s
# [CV] END ..............................kmeans__n_clusters=85; total time=   4.0s
# [CV] END ..............................kmeans__n_clusters=85; total time=   3.5s
# [CV] END ..............................kmeans__n_clusters=85; total time=   6.0s
# [CV] END ..............................kmeans__n_clusters=86; total time=   8.2s
# [CV] END ..............................kmeans__n_clusters=86; total time=   3.7s
# [CV] END ..............................kmeans__n_clusters=86; total time=   7.7s
# [CV] END ..............................kmeans__n_clusters=87; total time=   4.1s
# [CV] END ..............................kmeans__n_clusters=87; total time=   4.7s
# [CV] END ..............................kmeans__n_clusters=87; total time=   6.7s
# [CV] END ..............................kmeans__n_clusters=88; total time=   6.6s
# [CV] END ..............................kmeans__n_clusters=88; total time=   5.6s
# [CV] END ..............................kmeans__n_clusters=88; total time=   8.7s
# [CV] END ..............................kmeans__n_clusters=89; total time=   5.5s
# [CV] END ..............................kmeans__n_clusters=89; total time=   5.9s
# [CV] END ..............................kmeans__n_clusters=89; total time=   8.8s
# [CV] END ..............................kmeans__n_clusters=90; total time=   8.7s
# [CV] END ..............................kmeans__n_clusters=90; total time=   5.3s
# [CV] END ..............................kmeans__n_clusters=90; total time=   7.8s
# [CV] END ..............................kmeans__n_clusters=91; total time=   5.9s
# [CV] END ..............................kmeans__n_clusters=91; total time=   4.2s
# [CV] END ..............................kmeans__n_clusters=91; total time=   4.1s
# [CV] END ..............................kmeans__n_clusters=92; total time=   3.6s
# [CV] END ..............................kmeans__n_clusters=92; total time=   4.2s
# [CV] END ..............................kmeans__n_clusters=92; total time=   9.1s
# [CV] END ..............................kmeans__n_clusters=93; total time=   4.2s
# [CV] END ..............................kmeans__n_clusters=93; total time=   3.5s
# [CV] END ..............................kmeans__n_clusters=93; total time=   5.6s
# [CV] END ..............................kmeans__n_clusters=94; total time=   3.7s
# [CV] END ..............................kmeans__n_clusters=94; total time=   3.4s
# [CV] END ..............................kmeans__n_clusters=94; total time=   4.8s
# [CV] END ..............................kmeans__n_clusters=95; total time=   4.1s
# [CV] END ..............................kmeans__n_clusters=95; total time=   3.8s
# [CV] END ..............................kmeans__n_clusters=95; total time=   7.2s
# [CV] END ..............................kmeans__n_clusters=96; total time=   3.9s
# [CV] END ..............................kmeans__n_clusters=96; total time=   5.6s
# [CV] END ..............................kmeans__n_clusters=96; total time=   5.4s
# [CV] END ..............................kmeans__n_clusters=97; total time=   4.2s
# [CV] END ..............................kmeans__n_clusters=97; total time=   3.8s
# [CV] END ..............................kmeans__n_clusters=97; total time=   4.3s
# [CV] END ..............................kmeans__n_clusters=98; total time=   6.3s
# [CV] END ..............................kmeans__n_clusters=98; total time=   5.9s
# [CV] END ..............................kmeans__n_clusters=98; total time=   9.1s
# [CV] END ..............................kmeans__n_clusters=99; total time=   5.8s
# [CV] END ..............................kmeans__n_clusters=99; total time=   5.6s
# [CV] END ..............................kmeans__n_clusters=99; total time=   7.2s
# CPU times: total: 2h 1min 13s
# Wall time: 29min 28s
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('kmeans', KMeans(n_clusters=50)),
#                                        ('log_reg',
#                                         LogisticRegression(max_iter=50000))]),
#              param_grid={'kmeans__n_clusters': range(2, 100)}, verbose=2)

# %%
grid_clf.best_params_
# Out:
# {'kmeans__n_clusters': 64}

# %%
grid_clf.score(X_test, y_test)
# Out:
# 0.9733333333333334
